# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('IBM.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# # 1. Find a dataset you'd like to explore. This can be something you're familiar with or something new. Create a Jupyter notebook and then:

# %% [markdown]
# ## Choose one variable and plot that variable four different ways.

# %%
#Continuous variable PLOT 1
sns.distplot(df['DistanceFromHome'], color = 'g')

# %%
#Continuous variable PLOT 2
sns.set(style = 'darkgrid')
g = sns.factorplot(y="DistanceFromHome", data=df,
                   size=6, kind="violin", palette="pastel")
plt.show()
# Out:
# C:\Users\mzz00\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\mzz00\Anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Continuous variable PLOT 3
sns.boxplot(x = df['DistanceFromHome'])

# %%
#Continuous variable PLOT 4
sns.pointplot(x= 'DistanceFromHome', data = df, orient = 'v')

# %% [markdown]
# # Choose two continuous variables, and plot them three different ways.

# %%
#Two Continuous variables PLOT 1
sns.set(style="ticks")
sns.lmplot(x="Age", y="MonthlyIncome", data=df)

# %%
#Two Continuous variables PLOT 2
sns.set(style="whitegrid")
sns.catplot(x="Age", y="MonthlyIncome", data=df)

# %%
#Two Continuous variables PLOT 3
sns.jointplot(x="Age", y="MonthlyIncome", data=df, kind="kde", size = 8)
# Out:
# C:\Users\mzz00\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Choose one continuous variable and one categorical variable, and plot them six different ways.

# %%
#One continuous variable and one categorical variable PLOT 1
sns.set(style = 'darkgrid')
g = sns.factorplot(x="Education", y="MonthlyIncome", data=df[lambda df: df['MonthlyIncome'] < 50000
#One continuous variable and one categorical variable PLOT 2
sns.stripplot(x="neighbourhood_group", y="price", data=df[lambda df: df['price'] < 500], jitter=True, palette = 'pastel')],
                   size=5, kind="bar", palette="pastel",ci=95)
plt.show()
# Out:
# C:\Users\mzz00\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\mzz00\Anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#One continuous variable and one categorical variable PLOT 2
sns.stripplot(x="Education", y="MonthlyIncome", data=df[lambda df: df['MonthlyIncome'] < 50000], jitter=True, palette = 'pastel')

# %%
#One continuous variable and one categorical variable PLOT 3
sns.boxplot(x="Education", y="MonthlyIncome", data=df[lambda df: df['MonthlyIncome'] < 50000], palette = 'pastel')

# %%
#One continuous variable and one categorical variable PLOT 4
sns.pointplot(x="Education", y="MonthlyIncome", data=df[lambda df: df['MonthlyIncome'] < 50000], palette = 'pastel', ci = 99.99)

# %%
#One continuous variable and one categorical variable PLOT 5
sns.set(style = 'darkgrid')
g = sns.factorplot(x="Education", y="MonthlyIncome", data=df[lambda df: df['MonthlyIncome'] < 50000],
                   size=5, kind="violin", palette="pastel")
plt.show()
# Out:
# C:\Users\mzz00\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\mzz00\Anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#One continuous variable and one categorical variable PLOT 6
sns.set(style="whitegrid", palette="pastel", color_codes=True)
# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(x="Education", y="MonthlyIncome", hue="Attrition",
               split=True, inner="quart",
               palette={"Yes": "y", "No": "b"},
               data=df)
sns.despine(left=True)

# %% [markdown]
# # Find a dataset with at least four continuous variables and one categorical variable. Create one master plot that gives insight into the variables and their interrelationships, including:

# %% [markdown]
# * Probability distributions
# * Bivariate relationships
# * Whether the distributions or the relationships vary across groups
# * Accompany your plot with a written description of what you see.

# %%
def draw_subplots(var_Name,tittle_Name,nrow=1,ncol=1,idx=1,fz=10): # Define a common module for drawing subplots.
    ax = plt.subplot(nrow,ncol,idx)                   #  idx - position of subplot in the main plotting window
    ax.set_title('Distribution of '+var_Name)         #  fz - the font size of Tittle in the main plotting window
    plt.suptitle(tittle_Name, fontsize=fz)

numeric_columns = ['Age', 'MonthlyIncome', 'TotalWorkingYears','DistanceFromHome']

fig,ax = plt.subplots(1,1, figsize=(10,15))
j=0  # reset the counter to plot 
title_Str="Plotting the density distribution of various numeric variable"

for i in numeric_columns:
    j +=1
    draw_subplots(i,title_Str,4,1,j,20) # create a 1x3 subplots for plotting distribution plots
    sns.distplot(df[i])
    plt.xlabel('')

# %% [markdown]
# We can get some observations from Density plots. First, the employee's age is normally distributed and mainly distributed between 20 and 50, Anhd the mean of age is around 35.Secondly,the employee's monthly income is not normally distributed. Most of people is earning less than 7500 monthly and the distibution is sckewed to the left. Thirdly, the employee's total working years is also not normally distributed. Work years of the people is mainly distributed between 0 and 15 in a company. After that, it is quickly reduced and the distibution is sckewed to the left. Fourthly the employee's distance from home is also not normally distributed. Distance from home the people is mainly distributed between 1 to 11 in a company. After that, it is quickly reduced and the distibution is sckewed to the left.

# %%
sns.set(style="ticks")
sns.lmplot(x="Age", y="MonthlyIncome", data=df)

# %% [markdown]
# There is a positive relationship between age and monthly income. As employees get older, the monthly income will increase.

# %%
sns.set(style="ticks")
sns.lmplot(x="Age", y="TotalWorkingYears", data=df)

# %% [markdown]
# There is a positive relationship between age and Total Working Years. As employees get older, the Total Working Years income will increase.

# %%
sns.set(style="ticks")
sns.lmplot(x="Age", y="DistanceFromHome", data=df)

# %% [markdown]
# There are no relationships between age and the distance from home.

# %%
sns.set(style="ticks")
sns.lmplot(x="MonthlyIncome", y="TotalWorkingYears", data=df)

# %% [markdown]
# There is a positive relationship between Total Working Years and Monthly Income. The longer the employees works, the higher the monthly income will be.

# %%
sns.set(style="ticks")
sns.lmplot(x="MonthlyIncome", y="DistanceFromHome", data=df)

# %% [markdown]
# There are no relationships between Monthly Income and the distance from home.

# %%
sns.set(style="ticks")
sns.lmplot(x="TotalWorkingYears", y="DistanceFromHome", data=df)

# %% [markdown]
# There are no relationships between Total Working Years and the distance from home.

# %%
sns.set(style="ticks")
sns.lmplot(x="Age", y="MonthlyIncome", data=df[df['Gender']=='Male'])
sns.lmplot(x="Age", y="MonthlyIncome", data=df[df['Gender']=='Female'])

# %% [markdown]
# The relationships between age and monthly income are same across Male and Female.

# %%
sns.set(style="ticks")
sns.lmplot(x="Age", y="TotalWorkingYears", data=df[df['Gender']=='Male'])
sns.lmplot(x="Age", y="TotalWorkingYears", data=df[df['Gender']=='Female'])

# %% [markdown]
# The relationships between age and total working years are same across Male and Female.

# %%
sns.set(style="ticks")
sns.lmplot(x="Age", y="DistanceFromHome", data=df[df['Gender']=='Male'])
sns.lmplot(x="Age", y="DistanceFromHome", data=df[df['Gender']=='Female'])

# %% [markdown]
# The relationships between age and distance from home are same across Male and Female.

# %%
sns.set(style="ticks")
sns.lmplot(x="MonthlyIncome", y="TotalWorkingYears", data=df[df['Gender']=='Male'])
sns.lmplot(x="MonthlyIncome", y="TotalWorkingYears", data=df[df['Gender']=='Female'])

# %% [markdown]
# The relationships between monthly income and total working years are same across Male and Female.

# %%
sns.set(style="ticks")
sns.lmplot(x="MonthlyIncome", y="DistanceFromHome", data=df[df['Gender']=='Male'])
sns.lmplot(x="MonthlyIncome", y="DistanceFromHome", data=df[df['Gender']=='Female'])

# %% [markdown]
# Whether the relationships between monthly income and distance from home are same across Male and Female.

# %%
sns.set(style="ticks")
sns.lmplot(x="TotalWorkingYears", y="DistanceFromHome", data=df[df['Gender']=='Male'])
sns.lmplot(x="TotalWorkingYears", y="DistanceFromHome", data=df[df['Gender']=='Female'])

# %% [markdown]
# The relationships between total working years and distance from home are same across Male and Female.
